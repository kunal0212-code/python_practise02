# %% [markdown]
# <a href="https://colab.research.google.com/github/kunal0212-code/python_practise02/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!!!")
# Out:
# hello world!!!

# %%
print ('heloo world')
# Out:
# heloo world

# %%
print("happy student's day")
# Out:
# happy student's day

# %%
print('''happy kunall's day,
happy baigan day''')
# Out:
# happy kunall's day,
# happy baigan day

# %%
x = 102.5
y = 545
print (x,y)
# Out:
# 102.5 545

# %%
x,y = 125 , 1025.64
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
x == 100 , y == 150
print (x+y)
# Out:
# 1150.64
